# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # Surabaya

# %%
file_path = "D:/Lomba/DATATHON DICODING/inflasiwatch/data/final/df_merged_surabaya.xlsx"
df = pd.read_excel(file_path)

# %%
# Preview Data
print("Shape data:", df.shape)
print("\nKolom:")
print(df.columns.tolist())

print("\n5 baris pertama:")
print(df.head())

print("\nInfo dataset:")
print(df.info())
# Out:
# Shape data: (75, 22)
#
# Kolom:
# ['date', 'ihk_kel_01_mtm', 'ihk_kel_03_mtm', 'ihk_kel_06_mtm', 'gt_harga_beras', 'gt_harga_cabai', 'gt_harga_telur', 'gt_harga_daging_ayam', 'gt_harga_minyak_goreng', 'gt_harga_bawang', 'gt_tiket_pesawat', 'gt_tiket_kereta', 'gt_harga_bensin', 'kurs_usd_idr', 'bi_rate_percent', 'harga_bbm_pertamax', 'oceanic_nino_index', 'inflasi_general_mtm', 'inflasi_core_mtm', 'inflasi_administered_price_mtm', 'inflasi_volatile_good_mtm', 'ihk_umum_mtm']
#
# 5 baris pertama:
#         date  ihk_kel_01_mtm  ihk_kel_03_mtm  ihk_kel_06_mtm  gt_harga_beras  \
# 0 2020-01-01             NaN             NaN             NaN              35
# 1 2020-02-01            1.14           -0.01            0.08              55
# 2 2020-03-01            0.08            0.00           -0.68              49
# 3 2020-04-01           -0.47           -0.01           -1.19              73
# 4 2020-05-01           -0.12            0.01            1.72              72
#
#    gt_harga_cabai  gt_harga_telur  gt_harga_daging_ayam  \
# 0              43              54                    45
# 1              44              66                    58
# 2              42              54                    44
# 3              47              76                    92
# 4              47              99                    63
#
#    gt_harga_minyak_goreng  gt_harga_bawang  ...  gt_harga_bensin  \
# 0                       9               53  ...               55
# 1                      13               69  ...               47
# 2                      12               52  ...               44
# 3                      19               65  ...               39
# 4                      21               83  ...               47
#
#    kurs_usd_idr  bi_rate_percent  harga_bbm_pertamax  oceanic_nino_index  \
# 0   13663.56727             5.00                9200                 0.6
# 1   13707.27200             4.75                9000                 0.6
# 2   15118.60095             4.50                9000                 0.5
# 3   15788.09476             4.50                9000                 0.3
# 4   14831.66000             4.50                9000                 0.0
#
#    inflasi_general_mtm  inflasi_core_mtm  inflasi_administered_price_mtm  \
# 0                 0.39              0.19                           -0.28
# 1                 0.28              0.14                           -0.11
# 2                 0.10              0.29                           -0.19
# 3                 0.08              0.17                           -0.14
# 4                 0.07              0.06                            0.67
#
#    inflasi_volatile_good_mtm  ihk_umum_mtm
# 0                       1.93           NaN
# 1                       1.27          0.32
# 2                      -0.38          0.01
# 3                      -0.09         -0.16
# 4                      -0.50          0.21
#
# [5 rows x 22 columns]
#
# Info dataset:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 75 entries, 0 to 74
# Data columns (total 22 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   date                            75 non-null     datetime64[ns]
#  1   ihk_kel_01_mtm                  74 non-null     float64
#  2   ihk_kel_03_mtm                  74 non-null     float64
#  3   ihk_kel_06_mtm                  74 non-null     float64
#  4   gt_harga_beras                  75 non-null     int64
#  5   gt_harga_cabai                  75 non-null     int64
#  6   gt_harga_telur                  75 non-null     int64
#  7   gt_harga_daging_ayam            75 non-null     int64
#  8   gt_harga_minyak_goreng          75 non-null     int64
#  9   gt_harga_bawang                 75 non-null     int64
#  10  gt_tiket_pesawat                75 non-null     int64
#  11  gt_tiket_kereta                 75 non-null     int64
#  12  gt_harga_bensin                 75 non-null     int64
#  13  kurs_usd_idr                    75 non-null     float64
#  14  bi_rate_percent                 75 non-null     float64
#  15  harga_bbm_pertamax              75 non-null     int64
#  16  oceanic_nino_index              74 non-null     float64
#  17  inflasi_general_mtm             75 non-null     float64
#  18  inflasi_core_mtm                75 non-null     float64
#  19  inflasi_administered_price_mtm  75 non-null     float64
#  20  inflasi_volatile_good_mtm       75 non-null     float64
#  21  ihk_umum_mtm                    74 non-null     float64
# dtypes: datetime64[ns](1), float64(11), int64(10)
# memory usage: 13.0 KB
# None

# %%
# Cek Missing Values
print("Missing values per kolom:")
print(df.isnull().sum())
# Out:
# Missing values per kolom:
# date                              0
# ihk_kel_01_mtm                    1
# ihk_kel_03_mtm                    1
# ihk_kel_06_mtm                    1
# gt_harga_beras                    0
# gt_harga_cabai                    0
# gt_harga_telur                    0
# gt_harga_daging_ayam              0
# gt_harga_minyak_goreng            0
# gt_harga_bawang                   0
# gt_tiket_pesawat                  0
# gt_tiket_kereta                   0
# gt_harga_bensin                   0
# kurs_usd_idr                      0
# bi_rate_percent                   0
# harga_bbm_pertamax                0
# oceanic_nino_index                1
# inflasi_general_mtm               0
# inflasi_core_mtm                  0
# inflasi_administered_price_mtm    0
# inflasi_volatile_good_mtm         0
# ihk_umum_mtm                      1
# dtype: int64

# %%
# Duplicate Check
print("Jumlah data duplikat:", df.duplicated().sum())
# Out:
# Jumlah data duplikat: 0

# %%
# Statistik Deskriptif
print("Statistik numerik:")
print(df.describe())
# Out:
# Statistik numerik:
#                       date  ihk_kel_01_mtm  ihk_kel_03_mtm  ihk_kel_06_mtm  \
# count                   75       74.000000       74.000000       74.000000
# mean   2023-01-30 22:43:12        0.201081        0.043649        0.090811
# min    2020-01-01 00:00:00      -12.360000      -10.120000      -14.880000
# 25%    2021-07-16 12:00:00       -0.255000        0.000000       -0.247500
# 50%    2023-02-01 00:00:00        0.380000        0.025000        0.120000
# 75%    2024-08-16 12:00:00        1.040000        0.080000        0.495000
# max    2026-03-01 00:00:00        2.540000        9.520000        9.590000
# std                    NaN        1.759194        2.179953        2.231936
#
#        gt_harga_beras  gt_harga_cabai  gt_harga_telur  gt_harga_daging_ayam  \
# count       75.000000       75.000000       75.000000             75.000000
# mean        48.880000       50.573333       54.160000             50.066667
# min         28.000000       28.000000       23.000000             22.000000
# 25%         38.000000       42.000000       36.000000             40.500000
# 50%         42.000000       48.000000       56.000000             48.000000
# 75%         55.000000       58.500000       66.000000             57.000000
# max        100.000000      100.000000      100.000000            100.000000
# std         16.169675       13.806749       19.285928             12.880252
#
#        gt_harga_minyak_goreng  gt_harga_bawang  ...  gt_harga_bensin  \
# count               75.000000        75.000000  ...        75.000000
# mean                13.133333        47.346667  ...        43.066667
# min                  5.000000        28.000000  ...        29.000000
# 25%                  7.000000        39.500000  ...        36.000000
# 50%                 10.000000        46.000000  ...        40.000000
# 75%                 13.000000        52.000000  ...        46.000000
# max                100.000000       100.000000  ...       100.000000
# std                 13.271931        12.603617  ...        11.544665
#
#        kurs_usd_idr  bi_rate_percent  harga_bbm_pertamax  oceanic_nino_index  \
# count     75.000000        75.000000           75.000000           74.000000
# mean   15207.448583         4.823333        11440.000000           -0.117568
# min    13663.567270         3.500000         9000.000000           -1.200000
# 25%    14391.971355         3.750000         9000.000000           -0.800000
# 50%    15168.911360         4.750000        12300.000000           -0.300000
# 75%    15973.453970         5.750000        12800.000000            0.175000
# max    16826.971180         6.250000        14500.000000            2.100000
# std      876.652754         1.019053         1917.328519            0.816836
#
#        inflasi_general_mtm  inflasi_core_mtm  inflasi_administered_price_mtm  \
# count            75.000000         75.000000                        75.00000
# mean              0.218400          0.181333                         0.26840
# min              -0.760000         -0.030000                        -7.38000
# 25%               0.005000          0.125000                        -0.03500
# 50%               0.170000          0.170000                         0.12000
# 75%               0.375000          0.240000                         0.36000
# max               1.650000          0.420000                         6.53000
# std               0.361797          0.101200                         1.54599
#
#        inflasi_volatile_good_mtm  ihk_umum_mtm
# count                  75.000000     74.000000
# mean                    0.329733      0.102973
# min                    -2.900000    -10.820000
# 25%                    -0.555000      0.070000
# 50%                     0.280000      0.210000
# 75%                     1.285000      0.412500
# max                     2.950000      1.520000
# std                     1.296164      1.341466
#
# [8 rows x 22 columns]

# %%
# Distribusi Variabel Numerik
numeric_cols = df.select_dtypes(include=np.number).columns

df[numeric_cols].hist(figsize=(15, 10), bins=20)
plt.tight_layout()
plt.show()

# %%
# Korelasi Awal
corr = df[numeric_cols].corr()
print("\nCorrelation matrix:")
print(corr)

plt.figure(figsize=(10, 6))
plt.imshow(corr, cmap='coolwarm', aspect='auto')
plt.colorbar()
plt.xticks(range(len(corr.columns)), corr.columns, rotation=90)
plt.yticks(range(len(corr.columns)), corr.columns)
plt.title("Correlation Heatmap")
plt.tight_layout()
plt.show()
# Out:
# Correlation matrix:
#                                 ihk_kel_01_mtm  ihk_kel_03_mtm  \
# ihk_kel_01_mtm                        1.000000        0.221543
# ihk_kel_03_mtm                        0.221543        1.000000
# ihk_kel_06_mtm                        0.685934        0.188828
# gt_harga_beras                        0.158151        0.109519
# gt_harga_cabai                        0.131707       -0.104300
# gt_harga_telur                        0.068778        0.009076
# gt_harga_daging_ayam                  0.207505        0.130008
# gt_harga_minyak_goreng                0.153978        0.018794
# gt_harga_bawang                      -0.094995       -0.099307
# gt_tiket_pesawat                      0.031936        0.071253
# gt_tiket_kereta                       0.124988        0.019882
# gt_harga_bensin                       0.132883        0.029647
# kurs_usd_idr                         -0.035348        0.044390
# bi_rate_percent                      -0.108576       -0.031589
# harga_bbm_pertamax                   -0.037221       -0.012819
# oceanic_nino_index                   -0.227024       -0.058584
# inflasi_general_mtm                   0.329693        0.656643
# inflasi_core_mtm                      0.008545        0.031761
# inflasi_administered_price_mtm        0.055368        0.823922
# inflasi_volatile_good_mtm             0.489506       -0.016722
# ihk_umum_mtm                          0.891697        0.423532
#
#                                 ihk_kel_06_mtm  gt_harga_beras  \
# ihk_kel_01_mtm                        0.685934        0.158151
# ihk_kel_03_mtm                        0.188828        0.109519
# ihk_kel_06_mtm                        1.000000       -0.043630
# gt_harga_beras                       -0.043630        1.000000
# gt_harga_cabai                        0.020303        0.156179
# gt_harga_telur                        0.160858        0.116630
# gt_harga_daging_ayam                  0.116395        0.297406
# gt_harga_minyak_goreng                0.088604        0.245721
# gt_harga_bawang                       0.037010        0.207953
# gt_tiket_pesawat                     -0.030985       -0.019450
# gt_tiket_kereta                       0.014316       -0.058381
# gt_harga_bensin                       0.397669        0.268832
# kurs_usd_idr                         -0.105732        0.064633
# bi_rate_percent                      -0.188990        0.098134
# harga_bbm_pertamax                    0.036493       -0.014729
# oceanic_nino_index                   -0.308622        0.275940
# inflasi_general_mtm                   0.262128        0.180905
# inflasi_core_mtm                      0.049187       -0.048542
# inflasi_administered_price_mtm        0.286455        0.124510
# inflasi_volatile_good_mtm             0.050644        0.170638
# ihk_umum_mtm                          0.850815        0.029180
#
#                                 gt_harga_cabai  gt_harga_telur  \
# ihk_kel_01_mtm                        0.131707        0.068778
# ihk_kel_03_mtm                       -0.104300        0.009076
# ihk_kel_06_mtm                        0.020303        0.160858
# gt_harga_beras                        0.156179        0.116630
# gt_harga_cabai                        1.000000        0.508369
# gt_harga_telur                        0.508369        1.000000
# gt_harga_daging_ayam                  0.295457        0.633125
# gt_harga_minyak_goreng                0.541468        0.433099
# gt_harga_bawang                       0.142042        0.603582
# gt_tiket_pesawat                      0.032171        0.006910
# gt_tiket_kereta                       0.104099       -0.082586
# gt_harga_bensin                       0.264950        0.243760
# kurs_usd_idr                         -0.348855       -0.795462
# bi_rate_percent                      -0.335349       -0.646942
# harga_bbm_pertamax                   -0.105757       -0.578121
# oceanic_nino_index                   -0.221377       -0.238987
# inflasi_general_mtm                   0.158634        0.069700
# inflasi_core_mtm                      0.097515       -0.227490
# inflasi_administered_price_mtm       -0.031611        0.071674
# inflasi_volatile_good_mtm             0.275862        0.079290
# ihk_umum_mtm                         -0.001758        0.085424
#
#                                 gt_harga_daging_ayam  gt_harga_minyak_goreng  \
# ihk_kel_01_mtm                              0.207505                0.153978
# ihk_kel_03_mtm                              0.130008                0.018794
# ihk_kel_06_mtm                              0.116395                0.088604
# gt_harga_beras                              0.297406                0.245721
# gt_harga_cabai                              0.295457                0.541468
# gt_harga_telur                              0.633125                0.433099
# gt_harga_daging_ayam                        1.000000                0.382556
# gt_harga_minyak_goreng                      0.382556                1.000000
# gt_harga_bawang                             0.353972                0.250077
# gt_tiket_pesawat                            0.050631                0.061314
# gt_tiket_kereta                            -0.031104                0.043112
# gt_harga_bensin                             0.288510                0.331826
# kurs_usd_idr                               -0.414530               -0.402936
# bi_rate_percent                            -0.391349               -0.459849
# harga_bbm_pertamax                         -0.379594               -0.327606
# oceanic_nino_index                         -0.269940               -0.305619
# inflasi_general_mtm                         0.235232                0.106284
# inflasi_core_mtm                           -0.190204               -0.005467
# inflasi_administered_price_mtm              0.156295                0.041490
# inflasi_volatile_good_mtm                   0.241424                0.119964
# ihk_umum_mtm                                0.150735                0.109995
#
#                                 gt_harga_bawang  gt_tiket_pesawat  ...  \
# ihk_kel_01_mtm                        -0.094995          0.031936  ...
# ihk_kel_03_mtm                        -0.099307          0.071253  ...
# ihk_kel_06_mtm                         0.037010         -0.030985  ...
# gt_harga_beras                         0.207953         -0.019450  ...
# gt_harga_cabai                         0.142042          0.032171  ...
# gt_harga_telur                         0.603582          0.006910  ...
# gt_harga_daging_ayam                   0.353972          0.050631  ...
# gt_harga_minyak_goreng                 0.250077          0.061314  ...
# gt_harga_bawang                        1.000000          0.136172  ...
# gt_tiket_pesawat                       0.136172          1.000000  ...
# gt_tiket_kereta                        0.028171          0.885609  ...
# gt_harga_bensin                        0.192552          0.237094  ...
# kurs_usd_idr                          -0.583914         -0.204218  ...
# bi_rate_percent                       -0.346321          0.167214  ...
# harga_bbm_pertamax                    -0.464644          0.181213  ...
# oceanic_nino_index                     0.009143          0.267800  ...
# inflasi_general_mtm                   -0.104222          0.258788  ...
# inflasi_core_mtm                      -0.333044          0.112175  ...
# inflasi_administered_price_mtm        -0.071946          0.086753  ...
# inflasi_volatile_good_mtm              0.007624          0.279669  ...
# ihk_umum_mtm                          -0.072033         -0.020167  ...
#
#                                 gt_harga_bensin  kurs_usd_idr  \
# ihk_kel_01_mtm                         0.132883     -0.035348
# ihk_kel_03_mtm                         0.029647      0.044390
# ihk_kel_06_mtm                         0.397669     -0.105732
# gt_harga_beras                         0.268832      0.064633
# gt_harga_cabai                         0.264950     -0.348855
# gt_harga_telur                         0.243760     -0.795462
# gt_harga_daging_ayam                   0.288510     -0.414530
# gt_harga_minyak_goreng                 0.331826     -0.402936
# gt_harga_bawang                        0.192552     -0.583914
# gt_tiket_pesawat                       0.237094     -0.204218
# gt_tiket_kereta                        0.180972     -0.131845
# gt_harga_bensin                        1.000000     -0.196893
# kurs_usd_idr                          -0.196893      1.000000
# bi_rate_percent                       -0.272653      0.637785
# harga_bbm_pertamax                     0.033608      0.645228
# oceanic_nino_index                    -0.276570      0.260013
# inflasi_general_mtm                    0.317867      0.017434
# inflasi_core_mtm                       0.110847      0.284689
# inflasi_administered_price_mtm         0.346424      0.027208
# inflasi_volatile_good_mtm              0.069051     -0.073216
# ihk_umum_mtm                           0.177681     -0.050151
#
#                                 bi_rate_percent  harga_bbm_pertamax  \
# ihk_kel_01_mtm                        -0.108576           -0.037221
# ihk_kel_03_mtm                        -0.031589           -0.012819
# ihk_kel_06_mtm                        -0.188990            0.036493
# gt_harga_beras                         0.098134           -0.014729
# gt_harga_cabai                        -0.335349           -0.105757
# gt_harga_telur                        -0.646942           -0.578121
# gt_harga_daging_ayam                  -0.391349           -0.379594
# gt_harga_minyak_goreng                -0.459849           -0.327606
# gt_harga_bawang                       -0.346321           -0.464644
# gt_tiket_pesawat                       0.167214            0.181213
# gt_tiket_kereta                        0.237642            0.287440
# gt_harga_bensin                       -0.272653            0.033608
# kurs_usd_idr                           0.637785            0.645228
# bi_rate_percent                        1.000000            0.724692
# harga_bbm_pertamax                     0.724692            1.000000
# oceanic_nino_index                     0.664402            0.359607
# inflasi_general_mtm                   -0.061621            0.137131
# inflasi_core_mtm                       0.014763            0.239858
# inflasi_administered_price_mtm        -0.066465            0.129280
# inflasi_volatile_good_mtm             -0.015996           -0.004759
# ihk_umum_mtm                          -0.161623           -0.041847
#
#                                 oceanic_nino_index  inflasi_general_mtm  \
# ihk_kel_01_mtm                           -0.227024             0.329693
# ihk_kel_03_mtm                           -0.058584             0.656643
# ihk_kel_06_mtm                           -0.308622             0.262128
# gt_harga_beras                            0.275940             0.180905
# gt_harga_cabai                           -0.221377             0.158634
# gt_harga_telur                           -0.238987             0.069700
# gt_harga_daging_ayam                     -0.269940             0.235232
# gt_harga_minyak_goreng                   -0.305619             0.106284
# gt_harga_bawang                           0.009143            -0.104222
# gt_tiket_pesawat                          0.267800             0.258788
# gt_tiket_kereta                           0.299605             0.265937
# gt_harga_bensin                          -0.276570             0.317867
# kurs_usd_idr                              0.260013             0.017434
# bi_rate_percent                           0.664402            -0.061621
# harga_bbm_pertamax                        0.359607             0.137131
# oceanic_nino_index                        1.000000            -0.044118
# inflasi_general_mtm                      -0.044118             1.000000
# inflasi_core_mtm                         -0.118762             0.257715
# inflasi_administered_price_mtm           -0.061415             0.785477
# inflasi_volatile_good_mtm                 0.035167             0.558667
# ihk_umum_mtm                             -0.303955             0.307095
#
#                                 inflasi_core_mtm  \
# ihk_kel_01_mtm                          0.008545
# ihk_kel_03_mtm                          0.031761
# ihk_kel_06_mtm                          0.049187
# gt_harga_beras                         -0.048542
# gt_harga_cabai                          0.097515
# gt_harga_telur                         -0.227490
# gt_harga_daging_ayam                   -0.190204
# gt_harga_minyak_goreng                 -0.005467
# gt_harga_bawang                        -0.333044
# gt_tiket_pesawat                        0.112175
# gt_tiket_kereta                         0.120543
# gt_harga_bensin                         0.110847
# kurs_usd_idr                            0.284689
# bi_rate_percent                         0.014763
# harga_bbm_pertamax                      0.239858
# oceanic_nino_index                     -0.118762
# inflasi_general_mtm                     0.257715
# inflasi_core_mtm                        1.000000
# inflasi_administered_price_mtm          0.109000
# inflasi_volatile_good_mtm               0.004474
# ihk_umum_mtm                            0.048052
#
#                                 inflasi_administered_price_mtm  \
# ihk_kel_01_mtm                                        0.055368
# ihk_kel_03_mtm                                        0.823922
# ihk_kel_06_mtm                                        0.286455
# gt_harga_beras                                        0.124510
# gt_harga_cabai                                       -0.031611
# gt_harga_telur                                        0.071674
# gt_harga_daging_ayam                                  0.156295
# gt_harga_minyak_goreng                                0.041490
# gt_harga_bawang                                      -0.071946
# gt_tiket_pesawat                                      0.086753
# gt_tiket_kereta                                       0.040605
# gt_harga_bensin                                       0.346424
# kurs_usd_idr                                          0.027208
# bi_rate_percent                                      -0.066465
# harga_bbm_pertamax                                    0.129280
# oceanic_nino_index                                   -0.061415
# inflasi_general_mtm                                   0.785477
# inflasi_core_mtm                                      0.109000
# inflasi_administered_price_mtm                        1.000000
# inflasi_volatile_good_mtm                            -0.043981
# ihk_umum_mtm                                          0.260240
#
#                                 inflasi_volatile_good_mtm  ihk_umum_mtm
# ihk_kel_01_mtm                                   0.489506      0.891697
# ihk_kel_03_mtm                                  -0.016722      0.423532
# ihk_kel_06_mtm                                   0.050644      0.850815
# gt_harga_beras                                   0.170638      0.029180
# gt_harga_cabai                                   0.275862     -0.001758
# gt_harga_telur                                   0.079290      0.085424
# gt_harga_daging_ayam                             0.241424      0.150735
# gt_harga_minyak_goreng                           0.119964      0.109995
# gt_harga_bawang                                  0.007624     -0.072033
# gt_tiket_pesawat                                 0.279669     -0.020167
# gt_tiket_kereta                                  0.349632      0.036725
# gt_harga_bensin                                  0.069051      0.177681
# kurs_usd_idr                                    -0.073216     -0.050151
# bi_rate_percent                                 -0.015996     -0.161623
# harga_bbm_pertamax                              -0.004759     -0.041847
# oceanic_nino_index                               0.035167     -0.303955
# inflasi_general_mtm                              0.558667      0.307095
# inflasi_core_mtm                                 0.004474      0.048052
# inflasi_administered_price_mtm                  -0.043981      0.260240
# inflasi_volatile_good_mtm                        1.000000      0.157181
# ihk_umum_mtm                                     0.157181      1.000000
#
# [21 rows x 21 columns]

# %% [markdown]
# # Medan

# %% [markdown]
# # Makassar

# %% [markdown]
# # Jakarta

# %% [markdown]
# # Bandung
